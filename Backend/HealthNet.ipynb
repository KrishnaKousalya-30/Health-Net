# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
from PIL import Image
import pytesseract
import pytesseract
import shutil
import os
import random

# Load the image
image = Image.open('/content/Testing_Image.jpg')

# Perform OCR
#extracted_text = pytesseract.image_to_string(image)
extracted_text = pytesseract.image_to_string(image, lang='eng', config='--psm 6')

# Print the extracted text
print(extracted_text)
# Out:
# toon SURGERY OPERATIVE REPORT
# Patient name: MR number: Date of operation:
# ‘Abigail Houston 000843 1/13/2023
# ‘Account No: Height: Weight:
# 8472942 54 1301
# Preoperative diagnosis:
# ‘Appendiceal artery bleeding. Estimated blood loss.
# Post-operative diagnosis:
# Appendiceal artery bleeding has been stopped
# Operation performed: — Therapeutic abdominal surgery
# ‘Surgeon Martic Cole
# Anesthesia General
# Condition Stable
# Complications None
# Clinical findings:
# ‘A 22-year-old female visited our hospital because of abdominal pain as she sustained a fall from a ladder
# dat home. The patient then fell unconscious. We discussed operative treatment with her husband and on
# our recommendation he agreed to proceed with surgical treatment.
# Procedure:
# The patient was brought to the operating room #306 ond placed on the operating table, general
# anesthesia was administered at 3:29, After the patient fell asleep, we opened the epigastric incision and
# performed an emergency operation to stop bleeding. Two weeks after stopping the bleeding, the patient
# was brought for the appointment and she did not have complaints of any abdominal symptoms or
# bleeding for 3 months.
# ‘Authorization for release of information Cole
# Original: Medical record Copy: Patient ExhibitNo2  1-37-27846

# %%
import re
text = extracted_text
# Define the pattern to match "Operation performed: Value"
pattern = r"Operation performed:\s*(.*)"
# Search for the pattern in the text
match = re.search(pattern, text)
if match:
    operation_performed = match.group(1)
    R=operation_performed
    S=R.upper()
    print("Operation performed:", S)
else:
    print("Operation performed information not found.")
# Out:
# Operation performed: — THERAPEUTIC ABDOMINAL SURGERY

# %%
import pandas as pd

# Replace 'your_file.xlsx' with the path to your Excel file
file_path = '/content/Package_Name.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the DataFrame
print(df.head(10))
# Out:
#     Sno                                       PACKAGE NAME           CATEGORY  \
# 0  1329         CMU0579 :  — THERAPEUTIC ABDOMINAL SURGERY  BARIATRIC SURGERY
# 1  1330  CMU0580 : ROUXEN Y GASTRIC BYPASS FOR MORBID O...  BARIATRIC SURGERY
# 2  1219  CMU0496 : ACUTE MI (CONSERVATIVE MANAGEMENT WI...         CARDIOLOGY
# 3  1220  CMU0497 : ACUTE MI (CONSERVATIVE MANAGEMENT WI...         CARDIOLOGY
# 4  1221          CMU0498 : ACUTE MI WITH CARDIOGENIC SHOCK         CARDIOLOGY
# 5  1222             CMU0499 : ACUTE MI REQUIRING IABP PUMP         CARDIOLOGY
# 6  1223               CMU0500 : CONGESTIVE CARDIAC FAILURE         CARDIOLOGY
# 7  1224                   CMU0501 : INFECTIVE ENDOCARDITIS         CARDIOLOGY
# 8  1225                       CMU0502 : PULMONARY EMBOLISM         CARDIOLOGY
# 9  1226  CMU0503 : ARRYTHMIAS (SUPRAVENTRICULLAR / VENT...         CARDIOLOGY
#
#        A1      A2      A3      A4      A5      A6      S1      S2
# 0  168000  168000  168000  168000  168000  168000  168000  168000
# 1  190000  190000  190000  190000  190000  190000  190000  190000
# 2   21000   21000   18900   18900   18900   18900   21000   18900
# 3   31500   31500   28350   28350   28350   28350   31500   28350
# 4   37800   37800   34000   34000   34000   34000   37800   34000
# 5   56700   56700   51050   51050   51050   51050   56700   51050
# 6   50000   50000   45000   45000   45000   45000   50000   45000
# 7   33000   33000   29700   29700   29700   29700   33000   29700
# 8   40000   40000   36000   36000   36000   36000   40000   36000
# 9  100000  100000   90000   90000   90000   90000  100000   90000

# %%
import pandas as pd

# Specify the operation performed name
operation_performed_name = S  # Replace this with your operation performed name

# Filter the dataframe for rows where 'PACKAGE NAME' contains the operation performed name
filtered_df1 = df[df['PACKAGE NAME'].str.contains(operation_performed_name)]

# Print the filtered dataframe
if not filtered_df1.empty:
    print(f"All rows related to '{operation_performed_name}':")
    print(filtered_df1)
else:
    print(f"No rows found related to '{operation_performed_name}'")
# Out:
# All rows related to '— THERAPEUTIC ABDOMINAL SURGERY':
#     Sno                                PACKAGE NAME           CATEGORY  \
# 0  1329  CMU0579 :  — THERAPEUTIC ABDOMINAL SURGERY  BARIATRIC SURGERY
#
#        A1      A2      A3      A4      A5      A6      S1      S2
# 0  168000  168000  168000  168000  168000  168000  168000  168000

# %%
filtered_df1
# Out:
#     Sno                                PACKAGE NAME           CATEGORY  \
# 0  1329  CMU0579 :  — THERAPEUTIC ABDOMINAL SURGERY  BARIATRIC SURGERY
#
#        A1      A2      A3      A4      A5      A6      S1      S2
# 0  168000  168000  168000  168000  168000  168000  168000  168000

# %%
import pandas as pd

file_path = '/content/District_Names.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Get user input for district name
user_district = input("Enter the district name: ")

# Filter dataframe based on user input
filtered_df = df[df['DISTRICT NAME'] == user_district]

# Print hospital names if district matches
if not filtered_df.empty:
    print("Hospitals in", user_district)
    for index, row in filtered_df.iterrows():
        print(row['HOSPITAL NAME'])

    # Get user input for selected hospital name
    selected_hospital = input("Select a hospital name: ")

    # Filter dataframe based on selected hospital name
    selected_df = filtered_df[filtered_df['HOSPITAL NAME'] == selected_hospital]

    # Print hospital name and grade if hospital matches
    if not selected_df.empty:
        print("Hospital_Name:-------->",selected_df.iloc[0]['HOSPITAL NAME'], "Grade of the hospital:---------->",selected_df.iloc[0]['GRADE'])
    else:
        print("Hospital not found")
else:
    print("No hospitals found in", user_district)
# Out:
# Enter the district name: RAMANATHAPURAM
# Hospitals in RAMANATHAPURAM
# AASI MULTISPECIALITY HOSP, RAMANATHAPURAM, TN.
# AASI MULTISPECIALITY HOSP, RAMANATHAPURAM, TN.
# AASI MULTISPECIALITY HOSP, RAMANATHAPURAM, TN.
# AASI MULTISPECIALITY HOSP, RAMANATHAPURAM, TN.
# AASI MULTISPECIALITY HOSP, RAMANATHAPURAM, TN.
# AROGYA HOSPITAL, RAMANATHAPURAM TN.
# AROGYA HOSPITAL, RAMANATHAPURAM TN.
# AROGYA HOSPITAL, RAMANATHAPURAM TN.
# AROGYA HOSPITAL, RAMANATHAPURAM TN.
# AROGYA HOSPITAL, RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KAMUDHI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL KEELAKKARAI,RAMANATHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,MUDUKALATHUR,RAMANTHAPURAM TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,PARTHIBANUR,RAMANATHAPURAM,TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,RAMESHWARAM,RAMANATHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,THIRUVADANAI,RAMANTHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT HOSPITAL,UCHIPULI, RAMANATHAPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.HEAD QRTRS HOSP PARAMAKUDI,RAMANATHPURAM TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# GOVT.RAMANATHAPURAM MEDICAL COLLEGE,RAMANAD TN.
# KANAGAMANI HOSPITAL, RAMANATHAPURAM TN.
# KANAGAMANI HOSPITAL, RAMANATHAPURAM TN.
# KANAGAMANI HOSPITAL, RAMANATHAPURAM TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PIMS, PONDICHERRY TN.
# PPS HOSPITAL, RAMANATHAPURAM, TN.
# PPS HOSPITAL, RAMANATHAPURAM, TN.
# PPS HOSPITAL, RAMANATHAPURAM, TN.
# PPS HOSPITAL, RAMANATHAPURAM, TN.
# RAJAN CLINIC, RAMANATHAPURAM TN.
# RAJAN CLINIC, RAMANATHAPURAM TN.
# RAJAN CLINIC, RAMANATHAPURAM TN.
# RAJAN CLINIC, RAMANATHAPURAM TN.
# RAJAN CLINIC, RAMANATHAPURAM TN.
# RAJAN CLINIC, RAMANATHAPURAM TN.
# SRI SAKTHI HOSPITAL,TIRUNELVELI TN.?
# SRI SAKTHI HOSPITAL,TIRUNELVELI TN.?
# SRI SAKTHI HOSPITAL,TIRUNELVELI TN.?
# GOVT ERVADI TALUK HOSPITAL, RAMANATHAPURAM TN.
# GOVT MANDABAM TALUK HOSPITAL, RAMANATHAPURAM TN.
# GOVT PANAIKULAM TALUK HOSPITAL, RAMANATHAPURAM TN.
# GOVT KADALADI TALUK HOSPITAL, RAMANATHAPURAM TN.
# Select a hospital name: PIMS, PONDICHERRY TN.
# Hospital_Name:--------> PIMS, PONDICHERRY TN. Grade of the hospital:----------> A4

# %%
r1=("Hospital_Name:",selected_df.iloc[0]['HOSPITAL NAME'], "Grade of the hospital:",selected_df.iloc[0]['GRADE'])
r1
json_file_path = 'hospital_data.json'
with open(json_file_path, 'w') as json_file:
    json.dump(r1, json_file, indent=4)
print(f"Hospital data saved to {json_file_path}")
# Out:
# Hospital data saved to hospital_data.json

# %%
import json

# Open the JSON file
with open('/content/hospital_data.json', 'r') as file:
    data = json.load(file)
print(data[3])
# 'data' now contains the content of the JSON file
# Out:
# A4

# %%
filtered_df1
# Out:
#     Sno                                PACKAGE NAME           CATEGORY  \
# 0  1329  CMU0579 :  — THERAPEUTIC ABDOMINAL SURGERY  BARIATRIC SURGERY
#
#        A1      A2      A3      A4      A5      A6      S1      S2
# 0  168000  168000  168000  168000  168000  168000  168000  168000

# %%
df=filtered_df1

# %%
# Assuming your DataFrame is named 'df'
a4_values = df[data[3]]
print("Insurance_Value:",a4_values)
# Out:
# Insurance_Value: 0    168000
# Name: A4, dtype: int64

# %%
[Hospital: KANAGAMANI HOSPITAL, RAMANATHAPURAM TN.,
       Insurance: 168000,
       Location: RAMANATHAPURAM,
       Operation:THERAPEUTIC ABDOMINAL SURGERY]

# %%
Hospital_info=[]
Hospital_info.append(selected_df.iloc[0]['HOSPITAL NAME'])
Hospital_info.append(a4_values)
Hospital_info.append(user_district)
Hospital_info.append(S)

# %%
print(Hospital_info)
# Out:
# ['PIMS, PONDICHERRY TN.', 0    168000
# Name: A4, dtype: int64, 'RAMANATHAPURAM', '— THERAPEUTIC ABDOMINAL SURGERY']
